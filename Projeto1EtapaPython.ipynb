# %%
#Variáveis iniciais
faturamento_total = 0
nomes_produtos = []
custos_producao = []
precos_venda = []
estoque_atual = []
historico_vendas = [] #Lista para armazenar registros de cada venda
opcao_menu = 0

#Loop principal
while opcao_menu != 6:
    print("--- MENU PY INDÚSTRIAS ---")
    print("1. Cadastrar Produto")
    print("2. Registrar Produção (Entrada)")
    print("3. Registrar Venda (Saída)")
    print("4. Buscar Produto")
    print("5. Relatório de Vendas (Buscar Vendas)")
    print("6. Sair")
    opcao_menu = int(input("Opcao_menu"))

    #Estrutura de Decisão
    if opcao_menu == 1:
        nome = input("Nome do veículo: ")
        custo = float(input("Custo de produção: "))
        preco = float(input("Preço de venda: "))

        nomes_produtos.append(nome)
        custos_producao.append(custo)
        precos_venda.append(preco)
# Out:
# --- MENU PY INDÚSTRIAS ---
# 1. Cadastrar Produto
# 2. Registrar Produção (Entrada)
# 3. Registrar Venda (Saída)
# 4. Buscar Produto
# 5. Relatório de Vendas (Buscar Vendas)
# 6. Sair
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 24
#      22 if opcao_menu == 1:
#      23     nome = input("Nome do veículo: ")
# ---> 24     custo = float(input("Custo de produção: "))
#      25     preco = float(input("Preço de venda: "))
#      27     nomes_produtos.append(nome)
#
# ValueError: could not convert string to float: ''
